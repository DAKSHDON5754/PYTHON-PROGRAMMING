# %%
a=80
a*=2
a
# Out:
# 160

# %%
b=2
b/5
b
# Out:
# 2

# %%
c=23
c%5
c
# Out:
# 23

# %%
a=25
a-=12
a
# Out:
# 13

# %%
x=12
x//2
x
# Out:
# 12

# %%
a1=["Akku",20,"Bsc Data Science","AAFT"]
x=dict(a1)
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 a1=["Akku",20,"Bsc Data Science","AAFT"]
# ----> 2 x=dict(a1)
#       3 x
#
# ValueError: dictionary update sequence element #0 has length 4; 2 is required

# %%
x="A9@#d$T&7!mZ*"
len(x)

# %%
x.lower()

# %%
x.upper()

# %%
print(x[0])

# %%
x="A9@#d$T&7!mZ*"
x[-1]
# Out:
# '*'

# %%
main_string = "Hello, world!"
substring = "world"

if substring in main_string:
    print("Substring found!")
else:
    print("Substring not found.")
# Out:
# Substring found!

# %%
x="A9@#d$T&7!mZ*"
x[::-1]
# Out:
# '*Zm!7&T$d#@9A'

# %%
x[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x[::-1]
#
# TypeError: 'int' object is not subscriptable

# %%
y=list[x]
y
# Out:
# list['A9@#d$T&7!mZ*']

# %%
let = ['apple', 'banana', 'cherry']
len(let)
# Out:
# 3

# %%
let.append("Harry")
let
# Out:
# ['apple', 'banana', 'cherry', 'Harry']

# %%
 let.remove("apple")
let
# Out:
# ['banana', 'cherry', 'Harry']

# %%
let
# Out:
# ['banana', 'cherry', 'Harry']

# %%
print("Ascending")
let
# Out:
# Ascending
# ['banana', 'cherry', 'Harry']

# %%
print("descending")
let
# Out:
# descending
# ['banana', 'cherry', 'Harry']

# %%
let.sort(reverse=True)
print(let)
# Out:
# ['cherry', 'banana', 'Harry']

# %%
a=["Akku","Ram","Shivam","Keshav","Salman"]
a.sort()
a
# Out:
# ['Akku', 'Keshav', 'Ram', 'Salman', 'Shivam']

# %%
a.reverse()
a
# Out:
# ['Shivam', 'Salman', 'Ram', 'Keshav', 'Akku']

# %%
x=(
